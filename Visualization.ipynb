# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
cat = [ 49.775926,  36.688980,  22.172852,  12.257313,   2.787248]
dog = [35.421743,  21.837114,  12.104507,   5.394071,   2.032898]
motor = [25.390173,  17.993058, 10.106953,   4.124508,  0.865441]
aeroplane = [35.938249,  27.387151,  12.291797,   3.419320,   1.330493]
horse = [31.810703,  18.857668,   9.907533,   3.637889,  1.383298]
bus = [38.746901,  23.893710,  13.857681,  6.649706,  0.635619]

# %%
xaxis = [0.4, 0.5, 0.6, 0.7, 0.8]
ticks = range(len(xaxis))

# %%
from matplotlib import markers
from matplotlib.pyplot import figure
plt.plot(cat, label="cat", marker=".")
plt.plot(dog, label='dog', marker='o')
plt.plot(motor, label='motor', marker="*")
plt.plot(aeroplane, label='aeroplane', marker=".")
plt.plot(horse, label='horse', marker="o")
plt.plot(bus, label='bus', marker="*")
plt.xticks(ticks, xaxis)
plt.legend()
plt.title("DQN- Average Precison for 6 Classes")
plt.xlabel("IoU Threshold")
plt.ylabel("Average precision")
plt.show()
# plt.savefig("AP Curve.png")

# %%
cat2 = [69.301471,  59.007353,  45.955882,  33.639706,  15.808824 ]
dog2 = [59.304085,  46.444781,  34.341906,  22.692890,  13.161876]
motor2 = [50.000000,  42.366412,  31.679389,  20.229008,  9.160305]
aeroplane2 = [58.045977,  49.425287,  33.908046,  18.103448,  10.632184]
horse2 = [53.877551,  42.040816,  30.204082,  16.734694,  8.571429]
bus2 = [60.189573,  48.341232,  36.492891,  23.696682,  7.109005]

# %%
plt.plot(cat2, label="cat", marker=".")
plt.plot(dog2, label='dog', marker='o')
plt.plot(motor2, label='motor', marker="*")
plt.plot(aeroplane2, label='aeroplane', marker=".")
plt.plot(horse2, label='horse', marker="o")
plt.plot(bus2, label='bus', marker="*")
plt.xticks(ticks, xaxis)
plt.legend()
plt.title("DQN-Recall for 6 Classes")
plt.xlabel("IoU Threshold")
plt.ylabel("Recall")
plt.show()
